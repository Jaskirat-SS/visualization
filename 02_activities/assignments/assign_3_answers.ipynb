# %% [markdown]
# Data selected:
# Harvested Area, Production, Value and Average Price of  Mushrooms, Ontario, 1983-2024
# References: Statistics Canada, CANSIM table no. 32-10-0356-01
# Files for Assignment three:
# Python Files:
# 1. assign_3_answers.ipynb
# 2. assign_3_code&figures.ipynb
# R files:
# 1. Rcode_assign-3.R
# 2. Rplot.jpg
# Input files:
# 1. mushroom_2.csv
# 2. mushroom_en.csv

# %% [markdown]
# Question: What software did you use to create your data visualization?
# Answer: I used Python with libraries such as Matplotlib and Seaborn to create my data visualization. Also, I will be using R tidyverse package to visualise the dataset.

# %% [markdown]
# Question: Who is your intended audience?
# Answer: The data collected is from the Ontario's open data catologue that is on aggregated mushroom production and yields. The intended audience are farmers and mycologist looking to use mushroom production data to make decisions on growing mushrooms.

# %% [markdown]
# Question: What information or message are you trying to convey with your visualization?
# Answer: With the line graph the key message to be conveyed is that there is a strong upward trend of production with high correlation to harvested area. Additionally, all decades show positive growth with the growth being particularly high for the recent years indicating a high demand for mushroom products.

# %% [markdown]
# Question: What aspects of design did you consider when making your visualization? How did you apply them? With what elements of your plots?
# Answer: While making the graphs a few design principles were kept in mind such as:
#
# Cleveland & McGill's Perceptual Hierarchy: Figure types that use common scales such as line charts were to depict trends across years.
#
# Stephen Few's Dashboard Design: This principle was used to select the appropriate chart type for the particular data to be displayed

# %% [markdown]
# Question:How did you ensure that your data visualizations are reproducible? If the tool you used to make your data visualization is not reproducible, how will this impact your data visualization?
# Answer: To ensure the reproducibility of data visualizations, we used reliable softwares such as python and R. The code is well documented and all the packages used are contained in an environment which can be shared with anyone to replicate the graphs. If the software glitches then any conclusions or interpretations that we make from the data can not be trusted.

# %% [markdown]
# Question: How did you ensure that your data visualization is accessible?
# Answer: The data visualization were made accessible by having suitable big fonts, decreasing cognitive load and using color blind suitable colors along with displaying graphs in easy to understand terminology.

# %%
Question: Who are the individuals and communities who might be impacted by your visualization?
Answer: All the stakeholders that are involved in the production of mushrooms are likely to be impacted by the visualizations such as 
agricultural policy makers, farmers and even mycologists.

# %%
Question: How did you choose which features of your chosen dataset to include or exclude from 
your visualization?
Answer: Out of all the parameters displayed in the graph, I selected the ones which can convey the main trends of the data such as production
and harvested area.

# %%
Question: What ‘underwater labour’ contributed to your final data visualization product?
Answer: There was underwater labour involved in changing the excel sheet downloaded from the website
to python readable format, this step could come under the category of data processing.
